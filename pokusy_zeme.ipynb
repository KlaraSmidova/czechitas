# %%
for i in[2, 4, 5]:
    print(i)
# Out:
# 2
# 4
# 5

# %%
a = 2
a + 4
# Out:
# 6

# %%
import pandas as pd

# %%
staty = pd.read_json("staty.json")
staty.set_index("name", inplace=True)
staty
# Out:
#                   alpha2Code alpha3Code    capital   region        subregion  \
# name
# Afghanistan               AF        AFG      Kabul     Asia    Southern Asia
# Åland Islands             AX        ALA  Mariehamn   Europe  Northern Europe
# Albania                   AL        ALB     Tirana   Europe  Southern Europe
# Algeria                   DZ        DZA    Algiers   Africa  Northern Africa
# American Samoa            AS        ASM  Pago Pago  Oceania        Polynesia
# ...                      ...        ...        ...      ...              ...
# Wallis and Futuna         WF        WLF   Mata-Utu  Oceania        Polynesia
# Western Sahara            EH        ESH   El Aaiún   Africa  Northern Africa
# Yemen                     YE        YEM     Sana'a     Asia     Western Asia
# Zambia                    ZM        ZMB     Lusaka   Africa   Eastern Africa
# Zimbabwe                  ZW        ZWE     Harare   Africa   Eastern Africa
#
# ...

# %%
staty['area']
# Out:
# name
# Afghanistan           652230.0
# Åland Islands           1580.0
# Albania                28748.0
# Algeria              2381741.0
# American Samoa           199.0
#                        ...
# Wallis and Futuna        142.0
# Western Sahara        266000.0
# Yemen                 527968.0
# Zambia                752612.0
# Zimbabwe              390757.0
# Name: area, Length: 250, dtype: float64

# %%
staty['area'].sum()
# Out:
# 150290562.82

# %%
staty.area
# Out:
# name
# Afghanistan           652230.0
# Åland Islands           1580.0
# Albania                28748.0
# Algeria              2381741.0
# American Samoa           199.0
#                        ...
# Wallis and Futuna        142.0
# Western Sahara        266000.0
# Yemen                 527968.0
# Zambia                752612.0
# Zimbabwe              390757.0
# Name: area, Length: 250, dtype: float64

# %%
staty['population']/1_000_000
# Out:
# name
# Afghanistan          27.657145
# Åland Islands         0.028875
# Albania               2.886026
# Algeria              40.400000
# American Samoa        0.057100
#                        ...
# Wallis and Futuna     0.011750
# Western Sahara        0.510713
# Yemen                27.478000
# Zambia               15.933883
# Zimbabwe             14.240168
# Name: population, Length: 250, dtype: float64

# %%
staty[staty['population'] > 100_000_000]
# Out:
#                          alpha2Code alpha3Code           capital    region  \
# name
# Bangladesh                       BD        BGD             Dhaka      Asia
# Brazil                           BR        BRA          Brasília  Americas
# China                            CN        CHN           Beijing      Asia
# India                            IN        IND         New Delhi      Asia
# Indonesia                        ID        IDN           Jakarta      Asia
# Japan                            JP        JPN             Tokyo      Asia
# Mexico                           MX        MEX       Mexico City  Americas
# Nigeria                          NG        NGA             Abuja    Africa
# Pakistan                         PK        PAK         Islamabad      Asia
# Philippines                      PH        PHL            Manila      Asia
# Russian Federation               RU        RUS            Moscow    Europe
# ...

# %%
2+3*2
# Out:
# 8

# %%
staty[(staty['population']>20_000_000)&(staty['region']== 'Europe')]
# Out:
#                                                    alpha2Code alpha3Code  \
# name
# France                                                     FR        FRA
# Germany                                                    DE        DEU
# Italy                                                      IT        ITA
# Poland                                                     PL        POL
# Russian Federation                                         RU        RUS
# Spain                                                      ES        ESP
# Ukraine                                                    UA        UKR
# United Kingdom of Great Britain and Northern Ir...         GB        GBR
#
#                                                    capital  region  \
# name
# France                                               Paris  Europe
# Germany                                             Berlin  Europe
# Italy                                                 Rome  Europe
# ...
