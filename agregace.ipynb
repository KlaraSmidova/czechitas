# %%
import pandas as pd

# %%
u202 = pd.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/u202.csv")
u203 = pd.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/u203.csv")
u302 = pd.read_csv("https://kodim.cz/cms/assets/kurzy/python-data-1/python-pro-data-1/agregace-a-spojovani/u302.csv")

# %%
u202[u202['znamka'].isnull()]
# Out:
#    cisloStudenta  predmet  znamka den
# 0              1   Chemie     NaN  pá
# 9              9  Dějepis     NaN  pá

# %%
u202.dropna(inplace=True)
u203.dropna(inplace=True)
u302.dropna(inplace=True)

# %%
u202['mistnost'] = 'u202'
u203['mistnost'] = 'u203'
u302['mistnost'] = 'u302'

# %%
maturita = pd.concat([u202, u203, u302], ignore_index=True)
maturita
# Out:
#     cisloStudenta           predmet  znamka den mistnost
# 0               2           Dějepis     3.0  pá     u202
# 1               3        Matematika     2.0  út     u202
# 2               2  Společenské vědy     2.0  pá     u202
# 3               4          Biologie     1.0  pá     u202
# 4               5           Dějepis     1.0  po     u202
# 5               6            Fyzika     2.0  čt     u202
# 6               7           Dějepis     4.0  po     u202
# 7               8        Matematika     2.0  po     u202
# 8              10            Chemie     2.0  st     u202
# 9               3            Chemie     5.0  út     u202
# 10             11        Matematika     1.0  st     u202
# 11             12          Biologie     4.0  st     u202
# 12             10           Dějepis     5.0  st     u202
# 13              5  Společenské vědy     3.0  po     u203
# 14             13        Matematika     5.0  po     u203
# ...

# %%
maturita.to_csv('maturita.csv', index=False)
